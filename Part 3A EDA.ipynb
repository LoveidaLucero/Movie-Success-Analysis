# %% [markdown]
# # Part 3A EDA
# Loveida Lucero

# %% [markdown]
# **Imports**

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Load Data**

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_2001.info()
df_2001.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1357 entries, 0 to 1356
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1357 non-null   object
#  1   adult                  1356 non-null   float64
#  2   backdrop_path          747 non-null    object
#  3   belongs_to_collection  97 non-null     object
#  4   budget                 1356 non-null   float64
#  5   genres                 1356 non-null   object
#  6   homepage               107 non-null    object
#  7   id                     1356 non-null   float64
#  8   original_language      1356 non-null   object
#  9   original_title         1356 non-null   object
#  10  overview               1330 non-null   object
#  11  popularity             1356 non-null   float64
#  12  poster_path            1226 non-null   object
#  13  production_companies   1356 non-null   object
#  14  production_countries   1356 non-null   object
#  15  release_date           1344 non-null   object
#  16  revenue                1356 non-null   float64
#  17  runtime                1356 non-null   float64
#  18  spoken_languages       1356 non-null   object
#  19  status                 1356 non-null   object
#  20  tagline                566 non-null    object
#  21  title                  1356 non-null   object
#  22  video                  1356 non-null   float64
#  23  vote_average           1356 non-null   float64
#  24  vote_count             1356 non-null   float64
#  25  certification          424 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 275.8+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
#          id original_language    original_title  ...     revenue  runtime  \
# 0       NaN               NaN               NaN  ...         NaN      NaN
# 1   11232.0                en    Kate & Leopold  ...  76019048.0    118.0
# 2  151007.0                en  The Silent Force  ...         0.0     90.0
# 3   73549.0                en     The Dark Mist  ...         0.0    101.0
# 4   10696.0                en           Glitter  ...   5271666.0    104.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline             title  video  \
# 0                                                NaN               NaN    NaN
# 1  If they lived in the same century, they'd be p...    Kate & Leopold    0.0
# 2  They left him for dead... They should have fin...  The Silent Force    0.0
# 3                                                NaN     The Dark Mist    0.0
# 4   In music she found her dream, her love, herself.           Glitter    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1         6.320     1237.0         PG-13
# 2         5.000        3.0           NaN
# 3         3.500        2.0            PG
# 4         4.405      132.0         PG-13
#
# [5 rows x 26 columns]

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2002 = pd.read_csv('Data/final_tmdb_data_2002.csv.gz')
df_2002.info()
df_2002.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1295 entries, 0 to 1294
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1295 non-null   object
#  1   adult                  1294 non-null   float64
#  2   backdrop_path          775 non-null    object
#  3   belongs_to_collection  120 non-null    object
#  4   budget                 1294 non-null   float64
#  5   genres                 1294 non-null   object
#  6   homepage               106 non-null    object
#  7   id                     1294 non-null   float64
#  8   original_language      1294 non-null   object
#  9   original_title         1294 non-null   object
#  10  overview               1262 non-null   object
#  11  popularity             1294 non-null   float64
#  12  poster_path            1183 non-null   object
#  13  production_companies   1294 non-null   object
#  14  production_countries   1294 non-null   object
#  15  release_date           1283 non-null   object
#  16  revenue                1294 non-null   float64
#  17  runtime                1294 non-null   float64
#  18  spoken_languages       1294 non-null   object
#  19  status                 1294 non-null   object
#  20  tagline                587 non-null    object
#  21  title                  1294 non-null   object
#  22  video                  1294 non-null   float64
#  23  vote_average           1294 non-null   float64
#  24  vote_count             1294 non-null   float64
#  25  certification          445 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 263.2+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0096056    0.0  /95U3MUDXu4xSCmVLtWgargRipDi.jpg                   NaN
# 2  tt0118926    0.0  /qR3Dk3ctnrrxkAI6I472RhamIbu.jpg                   NaN
# 3  tt0119980    0.0                               NaN                   NaN
# 4  tt0120679    0.0  /s04Ds4xbJU7DzeGVyamccH4LoxF.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1         0.0                      [{'id': 18, 'name': 'Drama'}]
# 2         0.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3         0.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 4  12000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1                                  NaN  109809.0                en
# 2                                  NaN   20689.0                en
# 3                                  NaN  563364.0                en
# 4  https://www.miramax.com/movie/frida    1360.0                en
#
#           original_title  ...     revenue  runtime  \
# 0                    NaN  ...         NaN      NaN
# 1   Crime and Punishment  ...         0.0    126.0
# 2    The Dancer Upstairs  ...   5227348.0    132.0
# 3  Random Shooting in LA  ...         0.0     91.0
# 4                  Frida  ...  56298474.0    123.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1                                                NaN   Crime and Punishment
# 2  An honest man caught in a world of intrigue, p...    The Dancer Upstairs
# 3                                                NaN  Random Shooting in LA
# 4                             Prepare to be seduced.                  Frida
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.300       12.0           NaN
# 2    0.0         6.200       51.0             R
# 3    0.0         0.000        0.0           NaN
# 4    0.0         7.424     1911.0             R
#
# [5 rows x 26 columns]

# %% [markdown]
# # Merge 2001 and 2002 Data

# %%
dfs = [df_2001, df_2002]
df_combined = pd.concat(dfs)
df_combined.info()
df_combined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2652 entries, 0 to 1294
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2652 non-null   object
#  1   adult                  2650 non-null   float64
#  2   backdrop_path          1522 non-null   object
#  3   belongs_to_collection  217 non-null    object
#  4   budget                 2650 non-null   float64
#  5   genres                 2650 non-null   object
#  6   homepage               213 non-null    object
#  7   id                     2650 non-null   float64
#  8   original_language      2650 non-null   object
#  9   original_title         2650 non-null   object
#  10  overview               2592 non-null   object
#  11  popularity             2650 non-null   float64
#  12  poster_path            2409 non-null   object
#  13  production_companies   2650 non-null   object
#  14  production_countries   2650 non-null   object
#  15  release_date           2627 non-null   object
#  16  revenue                2650 non-null   float64
#  17  runtime                2650 non-null   float64
#  18  spoken_languages       2650 non-null   object
#  19  status                 2650 non-null   object
#  20  tagline                1153 non-null   object
#  21  title                  2650 non-null   object
#  22  video                  2650 non-null   float64
#  23  vote_average           2650 non-null   float64
#  24  vote_count             2650 non-null   float64
#  25  certification          869 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 559.4+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
#          id original_language    original_title  ...     revenue  runtime  \
# 0       NaN               NaN               NaN  ...         NaN      NaN
# 1   11232.0                en    Kate & Leopold  ...  76019048.0    118.0
# 2  151007.0                en  The Silent Force  ...         0.0     90.0
# 3   73549.0                en     The Dark Mist  ...         0.0    101.0
# 4   10696.0                en           Glitter  ...   5271666.0    104.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline             title  video  \
# 0                                                NaN               NaN    NaN
# 1  If they lived in the same century, they'd be p...    Kate & Leopold    0.0
# 2  They left him for dead... They should have fin...  The Silent Force    0.0
# 3                                                NaN     The Dark Mist    0.0
# 4   In music she found her dream, her love, herself.           Glitter    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1         6.320     1237.0         PG-13
# 2         5.000        3.0           NaN
# 3         3.500        2.0            PG
# 4         4.405      132.0         PG-13
#
# [5 rows x 26 columns]

# %% [markdown]
# ## How many movies had at least some valid financial information (values > 0 for budget OR revenue)?

# %%
# find total movies with valid budget
filter_budget = df_combined['budget'] >0
filter_budget.sum()
# Out:
# 616

# %%
# find total movies with valid revenue
filter_revenue = df_combined['revenue'] >0
filter_revenue.sum()
# Out:
# 519

# %%
filter_financial = filter_revenue & filter_budget
filter_financial.sum()
# Out:
# 409

# %%
# Remove any movies with 0's for budget AND revenue from the remaining visualizations.
df_filtered = df_combined[filter_financial]
df_filtered.info()
df_filtered.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 409 entries, 1 to 1262
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                409 non-null    object
#  1   adult                  409 non-null    float64
#  2   backdrop_path          400 non-null    object
#  3   belongs_to_collection  94 non-null     object
#  4   budget                 409 non-null    float64
#  5   genres                 409 non-null    object
#  6   homepage               80 non-null     object
#  7   id                     409 non-null    float64
#  8   original_language      409 non-null    object
#  9   original_title         409 non-null    object
#  10  overview               409 non-null    object
#  11  popularity             409 non-null    float64
#  12  poster_path            408 non-null    object
#  13  production_companies   409 non-null    object
#  14  production_countries   409 non-null    object
#  15  release_date           409 non-null    object
#  16  revenue                409 non-null    float64
#  17  runtime                409 non-null    float64
#  18  spoken_languages       409 non-null    object
#  19  status                 409 non-null    object
#  20  tagline                361 non-null    object
#  21  title                  409 non-null    object
#  22  video                  409 non-null    float64
#  23  vote_average           409 non-null    float64
#  24  vote_count             409 non-null    float64
#  25  certification          340 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 86.3+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
#         id original_language  original_title  ...     revenue  runtime  \
# 1  11232.0                en  Kate & Leopold  ...  76019048.0    118.0
# 4  10696.0                en         Glitter  ...   5271666.0    104.0
#
#                                     spoken_languages    status  \
# 1  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline           title  video  \
# 1  If they lived in the same century, they'd be p...  Kate & Leopold    0.0
# 4   In music she found her dream, her love, herself.         Glitter    0.0
#
#    vote_average vote_count certification
# 1         6.320     1237.0         PG-13
# 4         4.405      132.0         PG-13
#
# [2 rows x 26 columns]

# %%
print(f"There are {len(df_filtered)} movies with valid budget and revenue.")
# Out:
# There are 409 movies with valid budget/revenue.

# %% [markdown]
# ## How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
# Display null matrix
import missingno as msno
msno.matrix(df_filtered);

# %%
with pd.option_context('display.float_format',lambda x: f" {x:,.0f}"):
    display(df_filtered.groupby('certification')['imdb_id'].count())

sns.countplot(data=df_filtered, x='certification');
df_combined['certification'].value_counts(dropna=False);
# Out:
# certification
# G         11
# NR         5
# PG        34
# PG-13    131
# R        159
# Name: imdb_id, dtype: int64

# %% [markdown]
# ## What is the average revenue per certification category?

# %%
with pd.option_context('display.float_format',lambda x: f"$ {x:,.0f}"):
    display(df_filtered.groupby('certification')['revenue'].mean())

sns.barplot(data=df_filtered, x='certification', y='revenue');
# Out:
# certification
# G       $ 140,113,185
# NR       $ 12,159,247
# PG      $ 190,140,007
# PG-13   $ 110,288,305
# R        $ 46,208,961
# Name: revenue, dtype: float64

# %% [markdown]
# ## What is the average budget per certification category?

# %%
with pd.option_context('display.float_format',lambda x: f"$ {x:,.0f}"):
    display(df_filtered.groupby('certification')['budget'].mean())

sns.barplot(data=df_filtered, x='certification', y='budget');
# Out:
# certification
# G       $ 47,818,182
# NR       $ 5,420,000
# PG      $ 50,644,036
# PG-13   $ 43,683,422
# R       $ 27,382,076
# Name: budget, dtype: float64

# %% [markdown]
# ## Save Combined data as csv.gz File

# %%
df_filtered.to_csv(f"Data/tmdb_results_combined.csv.gz", compression="gzip", index=False)
