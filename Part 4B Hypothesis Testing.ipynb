# %% [markdown]
# # Part 4B Hypothesis Testing
# -Loveida Lucero

# %% [markdown]
# **Imports**

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Load Data**

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_2000.info()
df_2000.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1257 non-null   object
#  1   adult                  1256 non-null   float64
#  2   backdrop_path          715 non-null    object
#  3   belongs_to_collection  116 non-null    object
#  4   budget                 1256 non-null   float64
#  5   genres                 1256 non-null   object
#  6   homepage               64 non-null     object
#  7   id                     1256 non-null   float64
#  8   original_language      1256 non-null   object
#  9   original_title         1256 non-null   object
#  10  overview               1231 non-null   object
#  11  popularity             1256 non-null   float64
#  12  poster_path            1145 non-null   object
#  13  production_companies   1256 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_2001.info()
df_2001.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1360 entries, 0 to 1359
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1360 non-null   object
#  1   adult                  1359 non-null   float64
#  2   backdrop_path          747 non-null    object
#  3   belongs_to_collection  97 non-null     object
#  4   budget                 1359 non-null   float64
#  5   genres                 1359 non-null   object
#  6   homepage               107 non-null    object
#  7   id                     1359 non-null   float64
#  8   original_language      1359 non-null   object
#  9   original_title         1359 non-null   object
#  10  overview               1331 non-null   object
#  11  popularity             1359 non-null   float64
#  12  poster_path            1228 non-null   object
#  13  production_companies   1359 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2002 = pd.read_csv('Data/final_tmdb_data_2002.csv.gz')
df_2002.info()
df_2002.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1295 entries, 0 to 1294
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1295 non-null   object
#  1   adult                  1294 non-null   float64
#  2   backdrop_path          775 non-null    object
#  3   belongs_to_collection  120 non-null    object
#  4   budget                 1294 non-null   float64
#  5   genres                 1294 non-null   object
#  6   homepage               106 non-null    object
#  7   id                     1294 non-null   float64
#  8   original_language      1294 non-null   object
#  9   original_title         1294 non-null   object
#  10  overview               1262 non-null   object
#  11  popularity             1294 non-null   float64
#  12  poster_path            1183 non-null   object
#  13  production_companies   1294 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2003 = pd.read_csv('Data/final_tmdb_data_2003.csv.gz')
df_2003.info()
df_2003.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1347 entries, 0 to 1346
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1347 non-null   object
#  1   adult                  1346 non-null   float64
#  2   backdrop_path          739 non-null    object
#  3   belongs_to_collection  120 non-null    object
#  4   budget                 1346 non-null   float64
#  5   genres                 1346 non-null   object
#  6   homepage               156 non-null    object
#  7   id                     1346 non-null   float64
#  8   original_language      1346 non-null   object
#  9   original_title         1346 non-null   object
#  10  overview               1311 non-null   object
#  11  popularity             1346 non-null   float64
#  12  poster_path            1195 non-null   object
#  13  production_companies   1346 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2004 = pd.read_csv('Data/final_tmdb_data_2004.csv.gz')
df_2004.info()
df_2004.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1507 entries, 0 to 1506
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1507 non-null   object
#  1   adult                  1506 non-null   float64
#  2   backdrop_path          871 non-null    object
#  3   belongs_to_collection  124 non-null    object
#  4   budget                 1506 non-null   float64
#  5   genres                 1506 non-null   object
#  6   homepage               181 non-null    object
#  7   id                     1506 non-null   float64
#  8   original_language      1506 non-null   object
#  9   original_title         1506 non-null   object
#  10  overview               1474 non-null   object
#  11  popularity             1506 non-null   float64
#  12  poster_path            1352 non-null   object
#  13  production_companies   1506 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2005 = pd.read_csv('Data/final_tmdb_data_2005.csv.gz')
df_2005.info()
df_2005.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1684 entries, 0 to 1683
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1684 non-null   object
#  1   adult                  1683 non-null   float64
#  2   backdrop_path          943 non-null    object
#  3   belongs_to_collection  122 non-null    object
#  4   budget                 1683 non-null   float64
#  5   genres                 1683 non-null   object
#  6   homepage               243 non-null    object
#  7   id                     1683 non-null   float64
#  8   original_language      1683 non-null   object
#  9   original_title         1683 non-null   object
#  10  overview               1638 non-null   object
#  11  popularity             1683 non-null   float64
#  12  poster_path            1481 non-null   object
#  13  production_companies   1683 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2006 = pd.read_csv('Data/final_tmdb_data_2006.csv.gz')
df_2006.info()
df_2006.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1919 entries, 0 to 1918
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1919 non-null   object
#  1   adult                  1918 non-null   float64
#  2   backdrop_path          1059 non-null   object
#  3   belongs_to_collection  142 non-null    object
#  4   budget                 1918 non-null   float64
#  5   genres                 1918 non-null   object
#  6   homepage               315 non-null    object
#  7   id                     1918 non-null   float64
#  8   original_language      1918 non-null   object
#  9   original_title         1918 non-null   object
#  10  overview               1878 non-null   object
#  11  popularity             1918 non-null   float64
#  12  poster_path            1691 non-null   object
#  13  production_companies   1918 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2007 = pd.read_csv('Data/final_tmdb_data_2007.csv.gz')
df_2007.info()
df_2007.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1945 entries, 0 to 1944
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1945 non-null   object
#  1   adult                  1944 non-null   float64
#  2   backdrop_path          1114 non-null   object
#  3   belongs_to_collection  138 non-null    object
#  4   budget                 1944 non-null   float64
#  5   genres                 1944 non-null   object
#  6   homepage               403 non-null    object
#  7   id                     1944 non-null   float64
#  8   original_language      1944 non-null   object
#  9   original_title         1944 non-null   object
#  10  overview               1903 non-null   object
#  11  popularity             1944 non-null   float64
#  12  poster_path            1722 non-null   object
#  13  production_companies   1944 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2008 = pd.read_csv('Data/final_tmdb_data_2008.csv.gz')
df_2008.info()
df_2008.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2187 entries, 0 to 2186
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2187 non-null   object
#  1   adult                  2186 non-null   float64
#  2   backdrop_path          1186 non-null   object
#  3   belongs_to_collection  155 non-null    object
#  4   budget                 2186 non-null   float64
#  5   genres                 2186 non-null   object
#  6   homepage               512 non-null    object
#  7   id                     2186 non-null   float64
#  8   original_language      2186 non-null   object
#  9   original_title         2186 non-null   object
#  10  overview               2125 non-null   object
#  11  popularity             2186 non-null   float64
#  12  poster_path            1902 non-null   object
#  13  production_companies   2186 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2009 = pd.read_csv('Data/final_tmdb_data_2009.csv.gz')
df_2009.info()
df_2009.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2506 entries, 0 to 2505
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2506 non-null   object
#  1   adult                  2505 non-null   float64
#  2   backdrop_path          1376 non-null   object
#  3   belongs_to_collection  165 non-null    object
#  4   budget                 2505 non-null   float64
#  5   genres                 2505 non-null   object
#  6   homepage               691 non-null    object
#  7   id                     2505 non-null   float64
#  8   original_language      2505 non-null   object
#  9   original_title         2505 non-null   object
#  10  overview               2447 non-null   object
#  11  popularity             2505 non-null   float64
#  12  poster_path            2176 non-null   object
#  13  production_companies   2505 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2010 = pd.read_csv('Data/final_tmdb_data_2010.csv.gz')
df_2010.info()
df_2010.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2737 entries, 0 to 2736
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2737 non-null   object
#  1   adult                  2736 non-null   float64
#  2   backdrop_path          1519 non-null   object
#  3   belongs_to_collection  195 non-null    object
#  4   budget                 2736 non-null   float64
#  5   genres                 2736 non-null   object
#  6   homepage               794 non-null    object
#  7   id                     2736 non-null   float64
#  8   original_language      2736 non-null   object
#  9   original_title         2736 non-null   object
#  10  overview               2663 non-null   object
#  11  popularity             2736 non-null   float64
#  12  poster_path            2374 non-null   object
#  13  production_companies   2736 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2011 = pd.read_csv('Data/final_tmdb_data_2011.csv.gz')
df_2011.info()
df_2011.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3033 entries, 0 to 3032
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3033 non-null   object
#  1   adult                  3032 non-null   float64
#  2   backdrop_path          1704 non-null   object
#  3   belongs_to_collection  224 non-null    object
#  4   budget                 3032 non-null   float64
#  5   genres                 3032 non-null   object
#  6   homepage               806 non-null    object
#  7   id                     3032 non-null   float64
#  8   original_language      3032 non-null   object
#  9   original_title         3032 non-null   object
#  10  overview               2959 non-null   object
#  11  popularity             3032 non-null   float64
#  12  poster_path            2670 non-null   object
#  13  production_companies   3032 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2012 = pd.read_csv('Data/final_tmdb_data_2012.csv.gz')
df_2012.info()
df_2012.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2502 entries, 0 to 2501
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2502 non-null   object
#  1   adult                  2501 non-null   float64
#  2   backdrop_path          1545 non-null   object
#  3   belongs_to_collection  197 non-null    object
#  4   budget                 2501 non-null   float64
#  5   genres                 2501 non-null   object
#  6   homepage               691 non-null    object
#  7   id                     2501 non-null   float64
#  8   original_language      2501 non-null   object
#  9   original_title         2501 non-null   object
#  10  overview               2461 non-null   object
#  11  popularity             2501 non-null   float64
#  12  poster_path            2230 non-null   object
#  13  production_companies   2501 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2013 = pd.read_csv('Data/final_tmdb_data_2013.csv.gz')
df_2013.info()
df_2013.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   imdb_id  1 non-null      int64
# dtypes: int64(1)
# memory usage: 136.0 bytes
#    imdb_id
# 0        0

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2014 = pd.read_csv('Data/final_tmdb_data_2014.csv.gz')
df_2014.info()
df_2014.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3775 entries, 0 to 3774
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3775 non-null   object
#  1   adult                  3774 non-null   float64
#  2   backdrop_path          2357 non-null   object
#  3   belongs_to_collection  270 non-null    object
#  4   budget                 3774 non-null   float64
#  5   genres                 3774 non-null   object
#  6   homepage               882 non-null    object
#  7   id                     3774 non-null   float64
#  8   original_language      3774 non-null   object
#  9   original_title         3774 non-null   object
#  10  overview               3719 non-null   object
#  11  popularity             3774 non-null   float64
#  12  poster_path            3402 non-null   object
#  13  production_companies   3774 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2015 = pd.read_csv('Data/final_tmdb_data_2015.csv.gz')
df_2015.info()
df_2015.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3851 entries, 0 to 3850
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3851 non-null   object
#  1   adult                  3850 non-null   float64
#  2   backdrop_path          2506 non-null   object
#  3   belongs_to_collection  248 non-null    object
#  4   budget                 3850 non-null   float64
#  5   genres                 3850 non-null   object
#  6   homepage               1026 non-null   object
#  7   id                     3850 non-null   float64
#  8   original_language      3850 non-null   object
#  9   original_title         3850 non-null   object
#  10  overview               3757 non-null   object
#  11  popularity             3850 non-null   float64
#  12  poster_path            3580 non-null   object
#  13  production_companies   3850 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2016 = pd.read_csv('Data/final_tmdb_data_2016.csv.gz')
df_2016.info()
df_2016.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4090 entries, 0 to 4089
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4090 non-null   object
#  1   adult                  4089 non-null   float64
#  2   backdrop_path          2826 non-null   object
#  3   belongs_to_collection  293 non-null    object
#  4   budget                 4089 non-null   float64
#  5   genres                 4089 non-null   object
#  6   homepage               1192 non-null   object
#  7   id                     4089 non-null   float64
#  8   original_language      4089 non-null   object
#  9   original_title         4089 non-null   object
#  10  overview               3993 non-null   object
#  11  popularity             4089 non-null   float64
#  12  poster_path            3891 non-null   object
#  13  production_companies   4089 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2017 = pd.read_csv('Data/final_tmdb_data_2017.csv.gz')
df_2017.info()
df_2017.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4467 entries, 0 to 4466
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4467 non-null   object
#  1   adult                  4466 non-null   float64
#  2   backdrop_path          3329 non-null   object
#  3   belongs_to_collection  298 non-null    object
#  4   budget                 4466 non-null   float64
#  5   genres                 4466 non-null   object
#  6   homepage               1180 non-null   object
#  7   id                     4466 non-null   float64
#  8   original_language      4466 non-null   object
#  9   original_title         4466 non-null   object
#  10  overview               4386 non-null   object
#  11  popularity             4466 non-null   float64
#  12  poster_path            4367 non-null   object
#  13  production_companies   4466 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2018 = pd.read_csv('Data/final_tmdb_data_2018.csv.gz')
df_2018.info()
df_2018.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4698 entries, 0 to 4697
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4698 non-null   object
#  1   adult                  4697 non-null   float64
#  2   backdrop_path          3657 non-null   object
#  3   belongs_to_collection  290 non-null    object
#  4   budget                 4697 non-null   float64
#  5   genres                 4697 non-null   object
#  6   homepage               1275 non-null   object
#  7   id                     4697 non-null   float64
#  8   original_language      4697 non-null   object
#  9   original_title         4697 non-null   object
#  10  overview               4620 non-null   object
#  11  popularity             4697 non-null   float64
#  12  poster_path            4603 non-null   object
#  13  production_companies   4697 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2019 = pd.read_csv('Data/final_tmdb_data_2019.csv.gz')
df_2019.info()
df_2019.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4921 entries, 0 to 4920
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4921 non-null   object
#  1   adult                  4920 non-null   float64
#  2   backdrop_path          3923 non-null   object
#  3   belongs_to_collection  303 non-null    object
#  4   budget                 4920 non-null   float64
#  5   genres                 4920 non-null   object
#  6   homepage               1253 non-null   object
#  7   id                     4920 non-null   float64
#  8   original_language      4920 non-null   object
#  9   original_title         4920 non-null   object
#  10  overview               4823 non-null   object
#  11  popularity             4920 non-null   float64
#  12  poster_path            4852 non-null   object
#  13  production_companies   4920 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2020 = pd.read_csv('Data/final_tmdb_data_2020.csv.gz')
df_2020.info()
df_2020.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3964 entries, 0 to 3963
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3964 non-null   object
#  1   adult                  3963 non-null   float64
#  2   backdrop_path          3005 non-null   object
#  3   belongs_to_collection  211 non-null    object
#  4   budget                 3963 non-null   float64
#  5   genres                 3963 non-null   object
#  6   homepage               1118 non-null   object
#  7   id                     3963 non-null   float64
#  8   original_language      3963 non-null   object
#  9   original_title         3963 non-null   object
#  10  overview               3912 non-null   object
#  11  popularity             3963 non-null   float64
#  12  poster_path            3865 non-null   object
#  13  production_companies   3963 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2021 = pd.read_csv('Data/final_tmdb_data_2021.csv.gz')
df_2021.info()
df_2021.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4053 entries, 0 to 4052
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4053 non-null   object
#  1   adult                  4052 non-null   float64
#  2   backdrop_path          3204 non-null   object
#  3   belongs_to_collection  251 non-null    object
#  4   budget                 4052 non-null   float64
#  5   genres                 4052 non-null   object
#  6   homepage               1178 non-null   object
#  7   id                     4052 non-null   float64
#  8   original_language      4052 non-null   object
#  9   original_title         4052 non-null   object
#  10  overview               4004 non-null   object
#  11  popularity             4052 non-null   float64
#  12  poster_path            3984 non-null   object
#  13  production_companies   4052 non-null   object
# ...

# %%
# Load the data from your .csv.gz file into a new DataFrame.
df_2022 = pd.read_csv('Data/final_tmdb_data_2022.csv.gz')
df_2022.info()
df_2022.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3929 non-null   object
#  1   adult                  3928 non-null   float64
#  2   backdrop_path          3157 non-null   object
#  3   belongs_to_collection  236 non-null    object
#  4   budget                 3928 non-null   float64
#  5   genres                 3928 non-null   object
#  6   homepage               1225 non-null   object
#  7   id                     3928 non-null   float64
#  8   original_language      3928 non-null   object
#  9   original_title         3928 non-null   object
#  10  overview               3877 non-null   object
#  11  popularity             3928 non-null   float64
#  12  poster_path            3839 non-null   object
#  13  production_companies   3928 non-null   object
# ...

# %% [markdown]
# # Merge 2000-2022 Data

# %%
dfs = [df_2000, df_2001, df_2002, df_2003, df_2004, df_2005, df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2016, df_2017, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022]
df_combined = pd.concat(dfs)
df_combined.info()
df_combined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71585 entries, 0 to 3928
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                71585 non-null  object
#  1   adult                  71560 non-null  float64
#  2   backdrop_path          48412 non-null  object
#  3   belongs_to_collection  4906 non-null   object
#  4   budget                 71560 non-null  float64
#  5   genres                 71560 non-null  object
#  6   homepage               17770 non-null  object
#  7   id                     71560 non-null  float64
#  8   original_language      71560 non-null  object
#  9   original_title         71560 non-null  object
#  10  overview               70153 non-null  object
#  11  popularity             71560 non-null  float64
#  12  poster_path            66990 non-null  object
#  13  production_companies   71560 non-null  object
# ...

# %% [markdown]
# # Filter movies with at least some valid revenue information (values > 0 for revenue).

# %%
# find total movies with valid revenue
filter_revenue = df_combined['revenue'] >0
filter_revenue.sum()

# %%
# Remove any movies with 0's for budget AND revenue from the remaining visualizations.
df_filtered = df_combined[filter_revenue]
df_filtered.info()
df_filtered.head(2)

# %%
print(f"There are {len(df_filtered)} movies with valid revenue.")
